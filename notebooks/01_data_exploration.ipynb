# %% [markdown]
# # 01 - Data exploration
#
# Download the official archives, verify their checksums, and inspect the stable 49-industry panel. Canonical parsing logic lives in `src/industry_momentum/data.py`.

# %%
from pathlib import Path

from industry_momentum.data import prepare_data

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
bundle = prepare_data(ROOT / 'data' / 'raw')
bundle.stable_start, bundle.industry_returns.shape, bundle.industry_returns.index[[0, -1]]

# %%
assert bundle.industry_returns.shape[1] == 49
assert not bundle.industry_returns.isna().any().any()
bundle.industry_returns.describe().T[['mean', 'std', 'min', 'max']].head(10)
